# %%
# %matplotlib inline

# %%
import numpy
from sourmash_lib import fig
import pylab

# %% [markdown]
# # Metagenomics data from Global Ocean Sampling
#
# http://journals.plos.org/plosbiology/article?id=10.1371/journal.pbio.0050077
#
# Note - 454 data.

# %%
# !../../sourmash compare -o gos *.sig -k 21 > /dev/null
# !../../sourmash compare -o gos-noa *.sig --ignore-abundance -k 21 > /dev/null
# Out:
# # running sourmash subcommand: compare
# loading GS002.fa.gz.sig
# loading GS003.fa.gz.sig
# loading GS004.fa.gz.sig
# loading GS005.fa.gz.sig
# loading GS006.fa.gz.sig
# loading GS007.fa.gz.sig
# loading GS008.fa.gz.sig
# loading GS009.fa.gz.sig
# loading GS010.fa.gz.sig
# loading GS011.fa.gz.sig
# loading GS012.fa.gz.sig
# loading GS013.fa.gz.sig
# loading GS014.fa.gz.sig
# loading GS015.fa.gz.sig
# loading GS016.fa.gz.sig
# loading GS017.fa.gz.sig
# loading GS018.fa.gz.sig
# loading GS019.fa.gz.sig
# loading GS020.fa.gz.sig
# loading GS021.fa.gz.sig
# loading GS022.fa.gz.sig
# loading GS023.fa.gz.sig
# loading GS025.fa.gz.sig
# loading GS026.fa.gz.sig
# loading GS027.fa.gz.sig
# loading GS028.fa.gz.sig
# loading GS029.fa.gz.sig
# loading GS030.fa.gz.sig
# loading GS031.fa.gz.sig
# loading GS032.fa.gz.sig
# loading GS033.fa.gz.sig
# loading GS034.fa.gz.sig
# loading GS035.fa.gz.sig
# loading GS036.fa.gz.sig
# loading GS037.fa.gz.sig
# min similarity in matrix: 0.0
# ...

# %%
D, labels = fig.load_matrix_and_labels('gos')
_ = fig.plot_composite_matrix(D, labels, vmax=0.5)
numpy.min(D), numpy.max(D)
pylab.savefig('gos.pdf')

# %%
D, labels = fig.load_matrix_and_labels('gos-noa')
_ = fig.plot_composite_matrix(D, labels, vmax=0.2)
numpy.min(D), numpy.max(D)
# Out:
# (0.0, 1.0)
