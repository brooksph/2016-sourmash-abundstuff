# %%
# %matplotlib inline

# %%
import numpy
from sourmash_lib import fig
import pylab

# %% [markdown]
# # Large yeast data set / mRNAseq
#
# See https://github.com/bartongroup/profDGE48/

# %%
# !../sourmash compare -o yeast *.sig -k 21
# Out:
# # running sourmash subcommand: compare
# loading ERR458510.sig
# loading ERR458523.sig
# loading ERR458665.sig
# loading ERR458681.sig
# loading ERR458685.sig
# loading ERR458747.sig
# loading ERR458753.sig
# loading ERR458755.sig
# loading ERR458884.sig
# loading ERR458937.sig
# loading ERR458966.sig
# loading ERR459001.sig
# loading ERR459005.sig
# loading ERR459013.sig
# loading ERR459049.sig
# loading ERR459068.sig
# loading ERR459102.sig
# loading ERR459124.sig
# loading ERR459128.sig
# loading ERR459140.sig
# loading mut-1a.sig
# loading mut-1b.sig
# loading wt-1a.sig
# loading wt-1b.sig
# 0-           ERR458510	[ 1.     0.829  0.564  0.836  0.559  0.864  0.816  0.687  0.62   0.601
#   0.611  0.547  0.214  0.607  0.427  0.641  0.707  0.796  0.641  0.473
#   0.834  0.835  0.51   0.54 ]
# 1-           ERR458523	[ 0.829  1.     0.603  0.895  0.531  0.847  0.768  0.655  0.571  0.558
#   0.563  0.506  0.198  0.605  0.396  0.594  0.697  0.781  0.594  0.445
# ...

# %%
D, labels = fig.load_matrix_and_labels('yeast')
D = (D + D.T) / 2.0
_ = fig.plot_composite_matrix(D, labels, vmin=0.48)
numpy.min(D), numpy.max(D)
# Out:
# (0.15121682933743241, 1.0)
